# %%
# Read Household Power Consumption dataset

import pandas as pd

# 1. Load dataset
df = pd.read_csv("household_power_consumption.txt", sep=";", low_memory=False)

# 2. Show first rows
df.head()

# %%
# Sliding Window Example for Household Power Consumption Dataset

import pandas as pd
import numpy as np

# 1. Load dataset
df = pd.read_csv("household_power_consumption.txt", sep=";", low_memory=False)

# 2. Keep only the target column
********************

# 3. Convert values to numeric
df["Global_active_power"] = pd.to_numeric(df["Global_active_power"], errors="coerce")

# 4. Remove missing values
df = df.dropna()

# 5. Take a small sample for now
gap = df["Global_active_power"].values[:8]

print("Original Global_active_power time series:")
print(gap)

# 6. Create sliding window samples
L = 3

X = []
y = []

********************
********************
********************

X = np.array(X)
y = np.array(y)

# 7. Show training samples
print("\nSliding window samples with L = 3:")
for i in range(len(X)):
    print(f"{X[i]} -> {y[i]}")

# 8. Show shapes
print("\nX shape:", X.shape)
print("y shape:", y.shape)

# %% [markdown]
# #Basic RNN

# %%
# Create RNN sequences using lookback window L

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# 1. Load dataset
df = pd.read_csv("household_power_consumption.txt", sep=";", low_memory=False)

# 2. Keep target column
df = df[["Global_active_power"]]

# 3. Convert to numeric and remove missing values
df["Global_active_power"] = pd.to_numeric(df["Global_active_power"], errors="coerce")
df = df.dropna()

# 4. Use a small part for now
data = df["Global_active_power"].values[:10000].reshape(-1, 1)

# 5. Scale data
********************
********************

# 6. Choose lookback window L
L = 24

# 7. Create input sequences and targets
X = []
y = []

for i in range(len(data_scaled) - L):
    X.append(data_scaled[i:i+L])
    y.append(data_scaled[i+L])

X = np.array(X)
y = np.array(y)

# 8. Show shapes
print("Lookback window L:", L)
print("X shape:", X.shape)
print("y shape:", y.shape)

# 9. Show one training sample
print("\nFirst input sequence:")
print(X[0].flatten())

print("\nFirst target:")
print(y[0])

# %%
# X shape = (samples, time steps, features)
# y shape = (samples, target values)

# %%
# RNN model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

model = Sequential([
********************
    SimpleRNN(32, activation="tanh"),
********************
])

model.compile(optimizer="adam", loss="mse", metrics=["mae"])

model.summary()

# %%
# Train, evaluate, and predict

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np

# 1. Train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=False)

# 2. Early stopping
********************

# 3. Train model
history = model.fit(X_train, y_train, validation_split=0.20, epochs=50, batch_size=32, callbacks=[early_stop], verbose=1)

# 4. Evaluate model
test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)
print("Test MSE:", test_loss)
print("Test MAE:", test_mae)

# 5. Predict
y_pred = model.predict(X_test)

# 6. Extra evaluation metrics
********************
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
********************

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r2)

# 7. Compare actual vs predicted values
results = pd.DataFrame({"Actual": y_test.flatten(), "Predicted": y_pred.flatten()})
print(results.head(10))

# %%
import matplotlib.pyplot as plt

# Plot actual vs predicted values
plt.figure(figsize=(10, 5))
plt.plot(y_test[:200].flatten(), color="blue", label="Actual")
plt.plot(y_pred[:200].flatten(), color="orange", label="Predicted")
plt.title("Actual vs Predicted Global Active Power")
********************
plt.ylabel("Global Active Power")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #LSTM

# %%
# Create LSTM sequences using lookback window L

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# 1. Load dataset
df = pd.read_csv("household_power_consumption.txt", sep=";", low_memory=False)

# 2. Keep target column
df = df[["Global_active_power"]]

# 3. Convert to numeric and remove missing values
df["Global_active_power"] = pd.to_numeric(df["Global_active_power"], errors="coerce")
********************

# 4. Use a small part for now
data = df["Global_active_power"].values[:10000].reshape(-1, 1)

# 5. Scale data
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# 6. Choose lookback window L
L = 24

# 7. Create input sequences and targets
X = []
y = []

for i in range(len(data_scaled) - L):
    X.append(data_scaled[i:i+L])
    y.append(data_scaled[i+L])

X = np.array(X)
y = np.array(y)

# 8. Show shapes
print("Lookback window L:", L)
print("X shape:", X.shape)
print("y shape:", y.shape)

# 9. Show one training sample
print("\nFirst input sequence:")
print(X[0].flatten())

print("\nFirst target:")
print(y[0])

# %%
# LSTM model

from tensorflow.keras.models import Sequential
********************

model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(L, 1)),
********************
    Dense(1)
])

model.compile(optimizer="adam", loss="mse", metrics=["mae"])

model.summary()

# %%
# Train, evaluate, and predict

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import pandas as pd

# 1. Train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=False)

# 2. Early stopping
early_stop = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)

# 3. Train model
********************

# 4. Evaluate model
test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)

print("Test MSE:", test_loss)
print("Test MAE:", test_mae)

# 5. Predict
y_pred = model.predict(X_test)

# 6. Extra evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r2)

# 7. Compare actual vs predicted values
results = pd.DataFrame({
    "Actual": y_test.flatten(),
    "Predicted": y_pred.flatten()
})
print(results.head(10))

# %%
import matplotlib.pyplot as plt

# Plot actual vs predicted values
plt.figure(figsize=(10, 5))
plt.plot(y_test[:200].flatten(), color="blue", label="Actual")
plt.plot(y_pred[:200].flatten(), color="orange", label="Predicted")
plt.title("LSTM: Actual vs Predicted Global Active Power")
plt.xlabel("Time Step")
plt.ylabel("Global Active Power")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #GRU

# %%
# Create GRU sequences using lookback window L

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# 1. Load dataset
df = pd.read_csv("household_power_consumption.txt", sep=";", low_memory=False)

# 2. Keep target column
df = df[["Global_active_power"]]

# 3. Convert to numeric and remove missing values
df["Global_active_power"] = pd.to_numeric(df["Global_active_power"], errors="coerce")
df = df.dropna()

# 4. Use a small part for teaching
data = df["Global_active_power"].values[:10000].reshape(-1, 1)

# 5. Scale data
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# 6. Choose lookback window L
L = 24

# 7. Create input sequences and targets
X = []
y = []

for i in range(len(data_scaled) - L):
    X.append(data_scaled[i:i+L])
    y.append(data_scaled[i+L])

X = np.array(X)
y = np.array(y)

# 8. Show shapes
print("Lookback window L:", L)
print("X shape:", X.shape)
print("y shape:", y.shape)

# 9. Show one training sample
print("\nFirst input sequence:")
print(X[0].flatten())

print("\nFirst target:")
print(y[0])

# %%
# GRU model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense

model = Sequential([
********************
    GRU(32),
    Dense(1)
])

********************

model.summary()

# %%
# Train, evaluate, and predict

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import pandas as pd

# 1. Train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=False)

# 2. Early stopping
early_stop = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)

# 3. Train model
history = model.fit(X_train, y_train, validation_split=0.20, epochs=50, batch_size=32, callbacks=[early_stop], verbose=1)

# 4. Evaluate model
test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)

print("Test MSE:", test_loss)
print("Test MAE:", test_mae)

# 5. Predict
********************

# 6. Extra evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r2)

# 7. Compare actual vs predicted values
results = pd.DataFrame({
    "Actual": y_test.flatten(),
    "Predicted": y_pred.flatten()
})
print(results.head(10))
